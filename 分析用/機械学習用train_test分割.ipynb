# %% [markdown]
# SQLで取得したデータ(今回は想定)をtrain_data,test_dataに分割しておく
# bike_infoだけで良い

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#data読み込み
data = pd.read_csv('../data/アップロード用/bike_info.csv',index_col=0)
data.dropna(inplace=True)

# %%
test_data = data.sample(int(len(data)*0.2))
train_data = data.drop(test_data.index)

# %%
train_data.isnull().sum()
# Out:
# id                  0
# cost                0
# model_number        0
# model_year          0
# color               0
# mileage             0
# guarantee_period    0
# store_id            0
# dtype: int64

# %%
test_data.isnull().sum()
# Out:
# id                  0
# cost                0
# model_number        0
# model_year          0
# color               0
# mileage             0
# guarantee_period    0
# store_id            0
# dtype: int64

# %%
#偏りがないかを確認
sns.pairplot(train_data.drop(columns=['id','model_number','color']))
plt.show()

# %%
train_data.to_csv('../data/機械学習用/train_data.csv')
test_data.to_csv('../data/機械学習用/test_data.csv')
